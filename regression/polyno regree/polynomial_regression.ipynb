# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('Position_Salaries.csv')
X = df.iloc[: ,1:-1].values
y = df.iloc[: , -1].values

# %% [markdown]
# # New Section

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
a = LinearRegression()
a.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
b = PolynomialFeatures(degree = 4)
X_poly = b.fit_transform(X)
a_2 = LinearRegression()
a_2.fit(X_poly , y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X,a.predict(X),color='blue')
plt.title('Truth or Bluff (linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,y,color='green')
plt.plot(X,a_2.predict(X_poly),color='red')
plt.title('Truth or bluff (Polynomial regression)')
plt.xlabel('Position')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X1 = np.arange(min(X),max(X),0.1)
X1 = X1.reshape(len(X1),1)
plt.scatter(X,y,color='green')
plt.plot(X1,a_2.predict(b.fit_transform(X1)),color='yellow')
plt.title('truth and Bluff (Polynomial regression with higher accuracy)')
plt.xlabel('Position')
plt.ylabel('salary')
plt.show()
# Out:
# <ipython-input-22-998471637daa>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X1 = np.arange(min(X),max(X),0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
a.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
a_2.predict(b.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
